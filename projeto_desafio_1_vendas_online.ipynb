# %%
import pandas as pd
import numpy as np
import json

# %%
with open('dados_vendas_clientes.json', 'r') as f:
    json_bruto = json.load(f)

# %%
dados_normalizados = pd.json_normalize(json_bruto, record_path='dados_vendas')

# %%
dados_normalizados
# Out:
#   Data de venda                                            Cliente  \
# 0    06/06/2022  [@ANA _LUCIA 321, DieGO ARMANDIU 210, DieGO AR...
# 1    07/06/2022  [Isabely JOanes 738, Isabely JOanes 738, Isabe...
# 2    08/06/2022  [Isabely JOanes 738, JOãO Gabriel 671, Julya m...
# 3    09/06/2022  [Julya meireles 914, MaRIA Julia 444, MaRIA Ju...
# 4    10/06/2022  [MaRIA Julia 444, PEDRO PASCO 812, Paulo castr...
#
#                                 Valor da compra
# 0    [R$ 836,5, R$ 573,33, R$ 392,8, R$ 512,34]
# 1  [R$ 825,31, R$ 168,07, R$ 339,18, R$ 314,69]
# 2  [R$ 682,05, R$ 386,34, R$ 622,65, R$ 630,79]
# 3   [R$ 390,3, R$ 759,16, R$ 334,47, R$ 678,78]
# 4  [R$ 314,24, R$ 311,15, R$ 899,16, R$ 885,24]

# %%
colunas = list(dados_normalizados.columns)

# %%
colunas
# Out:
# ['Data de venda', 'Cliente', 'Valor da compra']

# %%
dados_normalizados = dados_normalizados.explode(colunas[1:])

# %%
dados_normalizados
# Out:
#   Data de venda             Cliente Valor da compra
# 0    06/06/2022     @ANA _LUCIA 321        R$ 836,5
# 0    06/06/2022  DieGO ARMANDIU 210       R$ 573,33
# 0    06/06/2022  DieGO ARMANDIU 210        R$ 392,8
# 0    06/06/2022  DieGO ARMANDIU 210       R$ 512,34
# 1    07/06/2022  Isabely JOanes 738       R$ 825,31
# 1    07/06/2022  Isabely JOanes 738       R$ 168,07
# 1    07/06/2022  Isabely JOanes 738       R$ 339,18
# 1    07/06/2022  Isabely JOanes 738       R$ 314,69
# 2    08/06/2022  Isabely JOanes 738       R$ 682,05
# 2    08/06/2022    JOãO Gabriel 671       R$ 386,34
# 2    08/06/2022  Julya meireles 914       R$ 622,65
# 2    08/06/2022  Julya meireles 914       R$ 630,79
# 3    09/06/2022  Julya meireles 914        R$ 390,3
# 3    09/06/2022     MaRIA Julia 444       R$ 759,16
# 3    09/06/2022     MaRIA Julia 444       R$ 334,47
# 3    09/06/2022     MaRIA Julia 444       R$ 678,78
# 4    10/06/2022     MaRIA Julia 444       R$ 314,24
# 4    10/06/2022     PEDRO PASCO 812       R$ 311,15
# 4    10/06/2022    Paulo castro 481       R$ 899,16
# 4    10/06/2022   Thiago fritzz 883       R$ 885,24

# %%
dados_normalizados.reset_index(drop=True, inplace=True)

# %%
dados_normalizados
# Out:
#    Data de venda             Cliente Valor da compra
# 0     06/06/2022     @ANA _LUCIA 321        R$ 836,5
# 1     06/06/2022  DieGO ARMANDIU 210       R$ 573,33
# 2     06/06/2022  DieGO ARMANDIU 210        R$ 392,8
# 3     06/06/2022  DieGO ARMANDIU 210       R$ 512,34
# 4     07/06/2022  Isabely JOanes 738       R$ 825,31
# 5     07/06/2022  Isabely JOanes 738       R$ 168,07
# 6     07/06/2022  Isabely JOanes 738       R$ 339,18
# 7     07/06/2022  Isabely JOanes 738       R$ 314,69
# 8     08/06/2022  Isabely JOanes 738       R$ 682,05
# 9     08/06/2022    JOãO Gabriel 671       R$ 386,34
# 10    08/06/2022  Julya meireles 914       R$ 622,65
# 11    08/06/2022  Julya meireles 914       R$ 630,79
# 12    09/06/2022  Julya meireles 914        R$ 390,3
# 13    09/06/2022     MaRIA Julia 444       R$ 759,16
# 14    09/06/2022     MaRIA Julia 444       R$ 334,47
# 15    09/06/2022     MaRIA Julia 444       R$ 678,78
# 16    10/06/2022     MaRIA Julia 444       R$ 314,24
# 17    10/06/2022     PEDRO PASCO 812       R$ 311,15
# 18    10/06/2022    Paulo castro 481       R$ 899,16
# 19    10/06/2022   Thiago fritzz 883       R$ 885,24

# %%
dados_normalizados.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Data de venda    20 non-null     str
#  1   Cliente          20 non-null     str
#  2   Valor da compra  20 non-null     str
# dtypes: str(3)
# memory usage: 612.0 bytes

# %%
dados_normalizados['Valor da compra'] = dados_normalizados['Valor da compra'].apply(lambda x: x.replace('R$ ', '').replace(',', '.').strip())

# %%
dados_normalizados['Valor da compra'] = dados_normalizados['Valor da compra'].astype(np.float64)

# %%
dados_normalizados.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Data de venda    20 non-null     str
#  1   Cliente          20 non-null     str
#  2   Valor da compra  20 non-null     float64
# dtypes: float64(1), str(2)
# memory usage: 612.0 bytes

# %%
dados_normalizados
# Out:
#    Data de venda             Cliente  Valor da compra
# 0     06/06/2022     @ANA _LUCIA 321           836.50
# 1     06/06/2022  DieGO ARMANDIU 210           573.33
# 2     06/06/2022  DieGO ARMANDIU 210           392.80
# 3     06/06/2022  DieGO ARMANDIU 210           512.34
# 4     07/06/2022  Isabely JOanes 738           825.31
# 5     07/06/2022  Isabely JOanes 738           168.07
# 6     07/06/2022  Isabely JOanes 738           339.18
# 7     07/06/2022  Isabely JOanes 738           314.69
# 8     08/06/2022  Isabely JOanes 738           682.05
# 9     08/06/2022    JOãO Gabriel 671           386.34
# 10    08/06/2022  Julya meireles 914           622.65
# 11    08/06/2022  Julya meireles 914           630.79
# 12    09/06/2022  Julya meireles 914           390.30
# 13    09/06/2022     MaRIA Julia 444           759.16
# 14    09/06/2022     MaRIA Julia 444           334.47
# 15    09/06/2022     MaRIA Julia 444           678.78
# 16    10/06/2022     MaRIA Julia 444           314.24
# 17    10/06/2022     PEDRO PASCO 812           311.15
# 18    10/06/2022    Paulo castro 481           899.16
# 19    10/06/2022   Thiago fritzz 883           885.24

# %%
dados_normalizados['Cliente'] =  (dados_normalizados['Cliente']
 .str.lower()
 .replace(r'[^a-zA-Zá-úÁ-Ú ]', ' ', regex=True))

# %%
dados_normalizados
# Out:
#    Data de venda             Cliente  Valor da compra
# 0     06/06/2022      ana  lucia               836.50
# 1     06/06/2022  diego armandiu               573.33
# 2     06/06/2022  diego armandiu               392.80
# 3     06/06/2022  diego armandiu               512.34
# 4     07/06/2022  isabely joanes               825.31
# 5     07/06/2022  isabely joanes               168.07
# 6     07/06/2022  isabely joanes               339.18
# 7     07/06/2022  isabely joanes               314.69
# 8     08/06/2022  isabely joanes               682.05
# 9     08/06/2022    joão gabriel               386.34
# 10    08/06/2022  julya meireles               622.65
# 11    08/06/2022  julya meireles               630.79
# 12    09/06/2022  julya meireles               390.30
# 13    09/06/2022     maria julia               759.16
# 14    09/06/2022     maria julia               334.47
# 15    09/06/2022     maria julia               678.78
# 16    10/06/2022     maria julia               314.24
# 17    10/06/2022     pedro pasco               311.15
# 18    10/06/2022    paulo castro               899.16
# 19    10/06/2022   thiago fritzz               885.24

# %%
dados_normalizados.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Data de venda    20 non-null     str
#  1   Cliente          20 non-null     str
#  2   Valor da compra  20 non-null     float64
# dtypes: float64(1), str(2)
# memory usage: 612.0 bytes

# %%
dados_normalizados['Data de venda'] = pd.to_datetime(dados_normalizados['Data de venda'])

# %%
dados_normalizados.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Data de venda    20 non-null     datetime64[us]
#  1   Cliente          20 non-null     str
#  2   Valor da compra  20 non-null     float64
# dtypes: datetime64[us](1), float64(1), str(1)
# memory usage: 612.0 bytes

# %%
dados_normalizados
# Out:
#    Data de venda             Cliente  Valor da compra
# 0     2022-06-06      ana  lucia               836.50
# 1     2022-06-06  diego armandiu               573.33
# 2     2022-06-06  diego armandiu               392.80
# 3     2022-06-06  diego armandiu               512.34
# 4     2022-07-06  isabely joanes               825.31
# 5     2022-07-06  isabely joanes               168.07
# 6     2022-07-06  isabely joanes               339.18
# 7     2022-07-06  isabely joanes               314.69
# 8     2022-08-06  isabely joanes               682.05
# 9     2022-08-06    joão gabriel               386.34
# 10    2022-08-06  julya meireles               622.65
# 11    2022-08-06  julya meireles               630.79
# 12    2022-09-06  julya meireles               390.30
# 13    2022-09-06     maria julia               759.16
# 14    2022-09-06     maria julia               334.47
# 15    2022-09-06     maria julia               678.78
# 16    2022-10-06     maria julia               314.24
# 17    2022-10-06     pedro pasco               311.15
# 18    2022-10-06    paulo castro               899.16
# 19    2022-10-06   thiago fritzz               885.24

# %%
dados_normalizados['Data de venda'] = dados_normalizados['Data de venda'].dt.strftime('%d/%m/%Y')

# %%
dados_normalizados
# Out:
#    Data de venda             Cliente  Valor da compra
# 0     06/06/2022      ana  lucia               836.50
# 1     06/06/2022  diego armandiu               573.33
# 2     06/06/2022  diego armandiu               392.80
# 3     06/06/2022  diego armandiu               512.34
# 4     06/07/2022  isabely joanes               825.31
# 5     06/07/2022  isabely joanes               168.07
# 6     06/07/2022  isabely joanes               339.18
# 7     06/07/2022  isabely joanes               314.69
# 8     06/08/2022  isabely joanes               682.05
# 9     06/08/2022    joão gabriel               386.34
# 10    06/08/2022  julya meireles               622.65
# 11    06/08/2022  julya meireles               630.79
# 12    06/09/2022  julya meireles               390.30
# 13    06/09/2022     maria julia               759.16
# 14    06/09/2022     maria julia               334.47
# 15    06/09/2022     maria julia               678.78
# 16    06/10/2022     maria julia               314.24
# 17    06/10/2022     pedro pasco               311.15
# 18    06/10/2022    paulo castro               899.16
# 19    06/10/2022   thiago fritzz               885.24

# %%
dados_normalizados.groupby(by=['Cliente'])['Valor da compra'].sum()
# Out:
# Cliente
#  ana  lucia            836.50
# diego armandiu        1478.47
# isabely joanes        2329.30
# joão gabriel           386.34
# julya meireles        1643.74
# maria julia           2086.65
# paulo castro           899.16
# pedro pasco            311.15
# thiago fritzz          885.24
# Name: Valor da compra, dtype: float64
